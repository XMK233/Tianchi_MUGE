# %%
# script_pth = "scripts/run_sft.sh"
# train_jsonl = "/mnt/d/forCoding_data/Tianchi_MUGE/originalData/ECommerce-IC/IC_train.jsonl"
# images_tsv = "/mnt/d/forCoding_data/Tianchi_MUGE/originalData/ECommerce-IC/IC_train.tsv"
# output_dir = "/mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-IC/plan_1/sub_plan_1/trained_models/sft"

# !bash {script_pth} {train_jsonl} {images_tsv} {output_dir}

# %%
# !head /mnt/d/forCoding_data/Tianchi_MUGE/originalData/ECommerce-IC/example_pred.jsonl
# Out:
# {"image_id": "02681bc44833e582df9025861cdaf9a1", "text": "孤身不孤单，租房也要温馨感"}
# {"image_id": "091ccce307d993fd86ecc9a268c97c13", "text": "摆件十足的风情，增添靓丽的色彩"}

# %%
script_pth = "scripts/run_generate.sh"
test_jsonl = "/mnt/d/forCoding_data/Tianchi_MUGE/originalData/ECommerce-IC/IC_valid.jsonl"
images_tsv = "/mnt/d/forCoding_data/Tianchi_MUGE/originalData/ECommerce-IC/IC_valid.tsv"
model_dir = "/mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-IC/plan_1/sub_plan_1/trained_models/sft"
output_jsonl = "/mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-IC/plan_1/sub_plan_1/outputs/preds_valid.jsonl"

## 最后四个参数分别是：beam_size，max_gen_len，pics_for_one_pred_round，num_pred_rounds
# !bash {script_pth} {test_jsonl} {images_tsv} {model_dir} {output_jsonl} 1 64 100 2

# !bash {script_pth} {test_jsonl} {images_tsv} {model_dir} {output_jsonl} 1 64 100 1 "cuda" 224 "bf16" "auto"
# !head {output_jsonl}
# Out:
# /home/xiuminke/miniconda3/envs/ml12/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# [2025-11-27 15:25:07,826] INFO:infer: Loading processor from /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-IC/plan_1/sub_plan_1/trained_models/sft
# [2025-11-27 15:25:08,345] INFO:infer: Detected LoRA adapter; loading base model: Qwen/Qwen2.5-VL-3B-Instruct
# `torch_dtype` is deprecated! Use `dtype` instead!
# [2025-11-27 15:25:08,599] INFO:accelerate.utils.modeling: We will use 90% of the memory on device 0 for storing the model, and 10% for the buffer to avoid OOM. You can set `max_memory` in to a higher value to use more memory (at your own risk).
# Loading checkpoint shards: 100%|██████████████████| 2/2 [00:20<00:00, 10.10s/it]
# ...

# %%
script_pth = "scripts/run_eval.sh"

# !bash {script_pth}

# %%
# !ls /mnt/d/HuggingFaceModels/

# %% [markdown]
# toolName: view_files
#
# status: success
#
#
# filePath: /mnt/d/forCoding_code/Tianchi_MUGE/ECommerce-IC/plan_1/sub_plan_1/scripts/run_sft.sh
# /mnt/d/forCoding_code/Tianchi_MUGE/ECommerce-IC/plan_1/sub_plan_1/scripts/run_scst.sh
# /mnt/d/forCoding_code/Tianchi_MUGE/ECommerce-IC/plan_1/sub_plan_1/scripts/run_generate.sh
# /mnt/d/forCoding_code/Tianchi_MUGE/ECommerce-IC/plan_1/sub_plan_1/scripts/run_eval.sh
#
#
#
#
# toolName: view_files
#
# status: success
#
#
# filePath: /mnt/d/forCoding_code/Tianchi_MUGE/ECommerce-IC/readme.md
#
# **执行顺序**
# - SFT 训练
#   - `bash ECommerce-IC/plan_1/sub_plan_1/scripts/run_sft.sh /mnt/d/forCoding_data/Tianchi_MUGE/originalData/ECommerce-IC/IC_train.jsonl /mnt/d/forCoding_data/Tianchi_MUGE/originalData/ECommerce-IC/IC_train.tsv /mnt/d/forCoding_code/Tianchi_MUGE/ECommerce-IC/plan_1/sub_plan_1/outputs/sft`
# - SCST 训练
#   - `bash ECommerce-IC/plan_1/sub_plan_1/scripts/run_scst.sh /mnt/d/forCoding_data/Tianchi_MUGE/originalData/ECommerce-IC/IC_train.jsonl /mnt/d/forCoding_data/Tianchi_MUGE/originalData/ECommerce-IC/IC_train.tsv /mnt/d/forCoding_code/Tianchi_MUGE/ECommerce-IC/plan_1/sub_plan_1/outputs/sft /mnt/d/forCoding_code/Tianchi_MUGE/ECommerce-IC/plan_1/sub_plan_1/outputs/scst`
# - 验证集生成
#   - `bash ECommerce-IC/plan_1/sub_plan_1/scripts/run_generate.sh /mnt/d/forCoding_data/Tianchi_MUGE/originalData/ECommerce-IC/IC_valid.jsonl /mnt/d/forCoding_data/Tianchi_MUGE/originalData/ECommerce-IC/IC_valid.tsv /mnt/d/forCoding_code/Tianchi_MUGE/ECommerce-IC/plan_1/sub_plan_1/outputs/scst /mnt/d/forCoding_code/Tianchi_MUGE/ECommerce-IC/plan_1/sub_plan_1/outputs/preds_valid.jsonl`
# - 验证集评测（CIDEr-D）
#   - `bash ECommerce-IC/plan_1/sub_plan_1/scripts/run_eval.sh /mnt/d/forCoding_data/Tianchi_MUGE/originalData/ECommerce-IC/IC_valid.jsonl /mnt/d/forCoding_code/Tianchi_MUGE/ECommerce-IC/plan_1/sub_plan_1/outputs/preds_valid.jsonl`
# - 测试集生成（提交文件）
#   - `bash ECommerce-IC/plan_1/sub_plan_1/scripts/run_generate.sh /mnt/d/forCoding_data/Tianchi_MUGE/originalData/ECommerce-IC/IC_test.jsonl /mnt/d/forCoding_data/Tianchi_MUGE/originalData/ECommerce-IC/IC_test.tsv /mnt/d/forCoding_code/Tianchi_MUGE/ECommerce-IC/plan_1/sub_plan_1/outputs/scst /mnt/d/forCoding_code/Tianchi_MUGE/ECommerce-IC/plan_1/sub_plan_1/outputs/preds_test.jsonl`
#
# - 说明
#   - 脚本已内置 `TORCH_HOME`、代理、`HF_ENDPOINT` 等环境变量，并统一使用 `cache_dir=/mnt/d/HuggingFaceModels/`。
#   - 若不训练 SCST，可将生成步骤中的 `MODEL_DIR` 改为 `outputs/sft`。
