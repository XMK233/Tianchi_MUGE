# %%
# !python step_3_1-10_履-基于9_cp1-txt和img共享投影头.py --mode actual_run
# Out:
# /home/xiuminke/miniconda3/envs/ml12/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Using device: cuda
# 2025-11-11 18:21:04,016 - INFO - 初始化数据加载器，数据目录: /mnt/d/forCoding_data/Tianchi_MUGE/originalData/Multimodal_Retrieval
# 2025-11-11 18:21:04,018 - INFO - 加载train查询数据: /mnt/d/forCoding_data/Tianchi_MUGE/originalData/Multimodal_Retrieval/MR_train_queries.jsonl
# 加载train查询数据: 248786it [00:00, 248979.28it/s]
# 2025-11-11 18:21:05,083 - INFO - 成功加载train查询数据，共248786条
# 2025-11-11 18:21:05,093 - INFO - 加载valid查询数据: /mnt/d/forCoding_data/Tianchi_MUGE/originalData/Multimodal_Retrieval/MR_valid_queries.jsonl
# 加载valid查询数据: 5008it [00:00, 314103.96it/s]
# 2025-11-11 18:21:05,112 - INFO - 成功加载valid查询数据，共5008条
# Optim groups: 16
# ...

# %%
# !python step_3_1-11_泰-基于9_cp1-相似度函数改为dot.py --mode actual_run
## 光看test感觉不出有什么出息。。。
# Out:
# /home/xiuminke/miniconda3/envs/ml12/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Using device: cuda
# 2025-11-12 00:02:53,765 - INFO - 初始化数据加载器，数据目录: /mnt/d/forCoding_data/Tianchi_MUGE/originalData/Multimodal_Retrieval
# 2025-11-12 00:02:53,766 - INFO - 加载train查询数据: /mnt/d/forCoding_data/Tianchi_MUGE/originalData/Multimodal_Retrieval/MR_train_queries.jsonl
# 加载train查询数据: 248786it [00:01, 240073.02it/s]
# 2025-11-12 00:02:54,875 - INFO - 成功加载train查询数据，共248786条
# 2025-11-12 00:02:54,887 - INFO - 加载valid查询数据: /mnt/d/forCoding_data/Tianchi_MUGE/originalData/Multimodal_Retrieval/MR_valid_queries.jsonl
# 加载valid查询数据: 5008it [00:00, 307055.82it/s]
# 2025-11-12 00:02:54,906 - INFO - 成功加载valid查询数据，共5008条
# ...

# %%
# 【TODO】跑这俩
# !python step_3_1-12_否_cp1-基于9_cp1-图文统一可学温度.py --mode actual_run
# !python step_3_1-12_否_cp2-基于9_cp1-图文不同可学温度.py --mode actual_run
# Out:
# /home/xiuminke/miniconda3/envs/ml12/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Using device: cuda
# 2025-11-12 09:58:39,367 - INFO - 初始化数据加载器，数据目录: /mnt/d/forCoding_data/Tianchi_MUGE/originalData/Multimodal_Retrieval
# 2025-11-12 09:58:39,368 - INFO - 加载train查询数据: /mnt/d/forCoding_data/Tianchi_MUGE/originalData/Multimodal_Retrieval/MR_train_queries.jsonl
# 加载train查询数据: 248786it [00:00, 254385.22it/s]
# 2025-11-12 09:58:40,415 - INFO - 成功加载train查询数据，共248786条
# 2025-11-12 09:58:40,426 - INFO - 加载valid查询数据: /mnt/d/forCoding_data/Tianchi_MUGE/originalData/Multimodal_Retrieval/MR_valid_queries.jsonl
# 加载valid查询数据: 5008it [00:00, 327845.71it/s]
# 2025-11-12 09:58:40,445 - INFO - 成功加载valid查询数据，共5008条
# ...

# %%
# !python step_3_1-6_讼_cp1-基于5_cp2-换图像模型1.py #--mode actual_run
# Out:
# /home/xiuminke/miniconda3/envs/ml12/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Using device: cuda
# 2025-11-12 14:52:07,399 - INFO - 初始化数据加载器，数据目录: /mnt/d/forCoding_data/Tianchi_MUGE/originalData/Multimodal_Retrieval
# 2025-11-12 14:52:07,400 - INFO - 加载train查询数据: /mnt/d/forCoding_data/Tianchi_MUGE/originalData/Multimodal_Retrieval/MR_train_queries.jsonl
# 加载train查询数据: 248786it [00:00, 251027.43it/s]
# 2025-11-12 14:52:08,461 - INFO - 成功加载train查询数据，共248786条
# 2025-11-12 14:52:08,473 - INFO - 加载valid查询数据: /mnt/d/forCoding_data/Tianchi_MUGE/originalData/Multimodal_Retrieval/MR_valid_queries.jsonl
# 加载valid查询数据: 5008it [00:00, 334050.17it/s]
# 2025-11-12 14:52:08,491 - INFO - 成功加载valid查询数据，共5008条
# ...

# %%
# !python step_3_1-13_同人_cp1-基于9_cp1-换convnext试试.py --mode actual_run
# Out:
# /home/xiuminke/miniconda3/envs/ml12/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Using device: cuda
# 2025-11-12 12:02:44,818 - INFO - 初始化数据加载器，数据目录: /mnt/d/forCoding_data/Tianchi_MUGE/originalData/Multimodal_Retrieval
# 2025-11-12 12:02:44,819 - INFO - 加载train查询数据: /mnt/d/forCoding_data/Tianchi_MUGE/originalData/Multimodal_Retrieval/MR_train_queries.jsonl
# 加载train查询数据: 248786it [00:00, 250791.47it/s]
# 2025-11-12 12:02:45,875 - INFO - 成功加载train查询数据，共248786条
# 2025-11-12 12:02:45,886 - INFO - 加载valid查询数据: /mnt/d/forCoding_data/Tianchi_MUGE/originalData/Multimodal_Retrieval/MR_valid_queries.jsonl
# 加载valid查询数据: 5008it [00:00, 340196.20it/s]
# 2025-11-12 12:02:45,904 - INFO - 成功加载valid查询数据，共5008条
# ...

# %%
# !ls /mnt/d/HuggingFaceModels/mo

# %%
# !python step_3_1-6_讼_cp3-基于5_cp2-换图像模型3.py --mode actual_run
## vit并没有更好 Recall@1=0.1012, Recall@5=0.2847, Recall@10=0.4056, MeanRecall=0.2638 (N=5008)
# Out:
# /home/xiuminke/miniconda3/envs/ml12/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Using device: cuda
# 2025-11-12 14:02:35,075 - INFO - 初始化数据加载器，数据目录: /mnt/d/forCoding_data/Tianchi_MUGE/originalData/Multimodal_Retrieval
# 2025-11-12 14:02:35,077 - INFO - 加载train查询数据: /mnt/d/forCoding_data/Tianchi_MUGE/originalData/Multimodal_Retrieval/MR_train_queries.jsonl
# 加载train查询数据: 248786it [00:00, 255604.24it/s]
# 2025-11-12 14:02:36,115 - INFO - 成功加载train查询数据，共248786条
# 2025-11-12 14:02:36,128 - INFO - 加载valid查询数据: /mnt/d/forCoding_data/Tianchi_MUGE/originalData/Multimodal_Retrieval/MR_valid_queries.jsonl
# 加载valid查询数据: 5008it [00:00, 357636.67it/s]
# 2025-11-12 14:02:36,145 - INFO - 成功加载valid查询数据，共5008条
# ...

# %%
# !python step_2_3-5_需_cp1-修正版.py # --mode actual_run
## 越改越混蛋。。。算了，暂时放弃。
# Out:
# /home/xiuminke/miniconda3/envs/ml12/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Using device: cuda
# 2025-11-12 16:07:12,098 - INFO - 初始化数据加载器，数据目录: /mnt/d/forCoding_data/Tianchi_MUGE/originalData/Multimodal_Retrieval
# 2025-11-12 16:07:12,100 - INFO - 加载train查询数据: /mnt/d/forCoding_data/Tianchi_MUGE/originalData/Multimodal_Retrieval/MR_train_queries.jsonl
# 加载train查询数据: 248786it [00:01, 245482.87it/s]
# 2025-11-12 16:07:13,181 - INFO - 成功加载train查询数据，共248786条
# 2025-11-12 16:07:13,192 - INFO - 加载valid查询数据: /mnt/d/forCoding_data/Tianchi_MUGE/originalData/Multimodal_Retrieval/MR_valid_queries.jsonl
# 加载valid查询数据: 5008it [00:00, 361346.54it/s]
# 2025-11-12 16:07:13,209 - INFO - 成功加载valid查询数据，共5008条
# ...

# %%
# ## 多解冻，schedule，llrd可能会有用，可以给convnext模型加上。
# !python step_3_1-14_大有-基于6_cp1-cnvnxt基础上多解冻、schd、llrd.py --mode actual_run
## Recall@1=0.1224, Recall@5=0.3193, Recall@10=0.4367, MeanRecall=0.2928 (N=5008) 没有更好。
# Out:
# /home/xiuminke/miniconda3/envs/ml12/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Using device: cuda
# 2025-11-12 16:21:18,621 - INFO - 初始化数据加载器，数据目录: /mnt/d/forCoding_data/Tianchi_MUGE/originalData/Multimodal_Retrieval
# 2025-11-12 16:21:18,623 - INFO - 加载train查询数据: /mnt/d/forCoding_data/Tianchi_MUGE/originalData/Multimodal_Retrieval/MR_train_queries.jsonl
# 加载train查询数据: 248786it [00:00, 253109.74it/s]
# 2025-11-12 16:21:19,671 - INFO - 成功加载train查询数据，共248786条
# 2025-11-12 16:21:19,684 - INFO - 加载valid查询数据: /mnt/d/forCoding_data/Tianchi_MUGE/originalData/Multimodal_Retrieval/MR_valid_queries.jsonl
# 加载valid查询数据: 5008it [00:00, 281452.40it/s]
# 2025-11-12 16:21:19,705 - INFO - 成功加载valid查询数据，共5008条
# ...

# %%
# !python step_3_1-15_谦_cp1-基于6_cp1-难例挖掘.py --mode actual_run
## Recall@1=0.1288, Recall@5=0.3403, Recall@10=0.4617, MeanRecall=0.3102 (N=5008)
## 再调整一下试试。Recall@1=0.0373, Recall@5=0.1296, Recall@10=0.2165, MeanRecall=0.1278 (N=5008)
# Out:
# /home/xiuminke/miniconda3/envs/ml12/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Using device: cuda
# 2025-11-12 19:17:03,048 - INFO - 初始化数据加载器，数据目录: /mnt/d/forCoding_data/Tianchi_MUGE/originalData/Multimodal_Retrieval
# 2025-11-12 19:17:03,049 - INFO - 加载train查询数据: /mnt/d/forCoding_data/Tianchi_MUGE/originalData/Multimodal_Retrieval/MR_train_queries.jsonl
# 加载train查询数据: 248786it [00:01, 245022.02it/s]
# 2025-11-12 19:17:04,130 - INFO - 成功加载train查询数据，共248786条
# 2025-11-12 19:17:04,141 - INFO - 加载valid查询数据: /mnt/d/forCoding_data/Tianchi_MUGE/originalData/Multimodal_Retrieval/MR_valid_queries.jsonl
# 加载valid查询数据: 5008it [00:00, 349275.42it/s]
# 2025-11-12 19:17:04,159 - INFO - 成功加载valid查询数据，共5008条
# ...

# %%
# !python step_3_1-15_谦_cp2-基于6_cp1-记忆队列.py --mode actual_run
## 训练3轮，效果不好。Recall@1=0.0333, Recall@5=0.1308, Recall@10=0.2131, MeanRecall=0.1257 (N=5008)
## 增多几个epoch试试？没卵用 Recall@1=0.0310, Recall@5=0.1184, Recall@10=0.2065, MeanRecall=0.1186 (N=5008)
# Out:
# /home/xiuminke/miniconda3/envs/ml12/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Using device: cuda
# 2025-11-13 00:26:59,598 - INFO - 初始化数据加载器，数据目录: /mnt/d/forCoding_data/Tianchi_MUGE/originalData/Multimodal_Retrieval
# 2025-11-13 00:26:59,600 - INFO - 加载train查询数据: /mnt/d/forCoding_data/Tianchi_MUGE/originalData/Multimodal_Retrieval/MR_train_queries.jsonl
# 加载train查询数据: 248786it [00:01, 246390.71it/s]
# 2025-11-13 00:27:00,688 - INFO - 成功加载train查询数据，共248786条
# 2025-11-13 00:27:00,699 - INFO - 加载valid查询数据: /mnt/d/forCoding_data/Tianchi_MUGE/originalData/Multimodal_Retrieval/MR_valid_queries.jsonl
# 加载valid查询数据: 5008it [00:00, 336889.73it/s]
# 2025-11-13 00:27:00,716 - INFO - 成功加载valid查询数据，共5008条
# ...

# %%
for ia in ["none", "jitter_flip", "grayscale_blur"][::-1]:
    for ta in ["none", "word_dropout", "random_swap"][::-1]:
        print("'" + f"{ia}_{ta}".center(100, "-"))
        # !python step_3_1-16_豫_cp3-基于6_cp1-图像和文本增强.py --image_aug {ia} --text_aug {ta} --mode actual_run
# Out:
# '-------------------------------------grayscale_blur_random_swap-------------------------------------
# ERROR! Session/line number was not unique in database. History logging moved to new session 690
# /home/xiuminke/miniconda3/envs/ml12/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Using device: cuda
# 2025-11-14 13:33:03,311 - INFO - 初始化数据加载器，数据目录: /mnt/d/forCoding_data/Tianchi_MUGE/originalData/Multimodal_Retrieval
# 2025-11-14 13:33:03,311 - INFO - 加载train查询数据: /mnt/d/forCoding_data/Tianchi_MUGE/originalData/Multimodal_Retrieval/MR_train_queries.jsonl
# 加载train查询数据: 248786it [00:00, 263818.87it/s]
# 2025-11-14 13:33:04,319 - INFO - 成功加载train查询数据，共248786条
# ...

# %%
for ia in ["none",][::-1]:
    for ta in ["none", "word_dropout", "random_swap"][::-1]:
        print("'" + f"{ia}_{ta}".center(100, "-"))
        # !python step_3_1-16_豫_cp3-基于6_cp1-图像和文本增强.py --image_aug {ia} --text_aug {ta} --mode actual_run
# Out:
# '------------------------------------------none_random_swap------------------------------------------
# /home/xiuminke/miniconda3/envs/ml12/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Using device: cuda
# 2025-11-14 21:29:32,893 - INFO - 初始化数据加载器，数据目录: /mnt/d/forCoding_data/Tianchi_MUGE/originalData/Multimodal_Retrieval
# 2025-11-14 21:29:32,894 - INFO - 加载train查询数据: /mnt/d/forCoding_data/Tianchi_MUGE/originalData/Multimodal_Retrieval/MR_train_queries.jsonl
# 加载train查询数据: 248786it [00:00, 255310.62it/s]
# 2025-11-14 21:29:33,935 - INFO - 成功加载train查询数据，共248786条
# 2025-11-14 21:29:33,945 - INFO - 加载valid查询数据: /mnt/d/forCoding_data/Tianchi_MUGE/originalData/Multimodal_Retrieval/MR_valid_queries.jsonl
# ...
