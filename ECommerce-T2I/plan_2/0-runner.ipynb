# %%
# !python 23_蒙-基于10_14、15、16、18的综合.py
# !python 23_蒙-基于10_14、15、16、18的综合.py
# !python 23_蒙-基于10_14、15、16、18的综合.py
# Out:
# /home/xiuminke/miniconda3/envs/ml12/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 成功导入 diffusers 库
# 使用设备: cuda
# 成功加载标签数据: 1 条记录, 1 个类别
# 电商文本到图像生成 - Diffusion 版
#
# === 开始训练 (Diffusion Mode) ===
# 检查模型保存目录: /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-T2I/plan_1/models/v23
# 发现最新检查点文件: /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-T2I/plan_1/models/v23/latest_checkpoint.ckpt
# 当前分片已完成，将从分片 4 开始训练
# SD VAE模型加载成功
#
# === 加载最新检查点: /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-T2I/plan_1/models/v23/latest_checkpoint.ckpt ===
# 模型状态加载成功
# 优化器状态加载成功
# 梯度缩放器状态加载成功
# 成功加载检查点
# 检查点保存时的损失: 0.1834
#
# === 训练参数设置 ===
# 总训练图片数: 4000
# 每次加载图片数: 1000
# 总分片数: 4
# 每个分片训练轮数: 5
# 批次大小: 4
#
# === 所有分片训练完成 ===
#
# 准备验证数据...
#
# === 开始生成图像 ===
# ...

# %%
6+8+9
# Out:
# 23

# %%
# !python 22_屯-基于10_丢弃sdvae生成latent的操作.py
# Out:
# /home/xiuminke/miniconda3/envs/ml12/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 成功导入 diffusers 库
# 使用设备: cuda
# 强制重新训练，删除模型目录: /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-T2I/plan_1/models/v22
# 电商文本到图像生成 - Diffusion 版
#
# === 开始训练 (Diffusion Mode) ===
# 检查模型保存目录: /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-T2I/plan_1/models/v22
# 没有发现检查点，将从头开始训练
#
# === 训练参数设置 ===
# 总训练图片数: 4000
# 每次加载图片数: 1000
# 总分片数: 4
# 每个分片训练轮数: 5
# 批次大小: 4
#
# === 加载第 1/4 个分片 (1000 张图片) ===
# 分片 1/4 - epoch 1/5: 100%|██████| 250/250 [00:23<00:00, 10.43it/s, loss=0.0631]
# 分片 1/4 - Epoch 1/5, 平均损失: 0.2216
#
# === 保存检查点到 /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-T2I/plan_1/models/v22/latest_checkpoint.ckpt ===
# 检查点保存成功
# ...

# %% [markdown]
#  14～21的表现汇总：
#
#  ![image.png](attachment:6ea0a72a-4d95-4246-88f6-0dc3dc32f54e.png)

# %%
# !python 15_节-基于10_loss_辅助分类头（多任务）.py
# !python 15_节-基于10_loss_辅助分类头（多任务）.py
# !python 15_节-基于10_loss_辅助分类头（多任务）.py
# Out:
# /home/xiuminke/miniconda3/envs/ml12/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 成功导入 diffusers 库
# 使用设备: cuda
# 电商文本到图像生成 - Diffusion 版
#
# === 开始训练 (Diffusion Mode) ===
# 检查模型保存目录: /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-T2I/plan_1/models/v15
# 发现最新检查点文件: /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-T2I/plan_1/models/v15/latest_checkpoint.ckpt
# 当前分片已完成，将从分片 4 开始训练
# SD VAE模型加载成功
#
# === 加载最新检查点: /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-T2I/plan_1/models/v15/latest_checkpoint.ckpt ===
# 模型状态加载成功
# 优化器状态加载成功
# 梯度缩放器状态加载成功
# 成功加载检查点
# 检查点保存时的损失: 0.3257
#
# === 训练参数设置 ===
# 总训练图片数: 4000
# 每次加载图片数: 1000
# 总分片数: 4
# 每个分片训练轮数: 5
# 批次大小: 4
#
# === 所有分片训练完成 ===
#
# 准备验证数据...
#
# === 开始生成图像 ===
# ...

# %%
# !python 16_中孚-基于10_loss_InfoNCE_对比约束（标签原型）.py
# !python 16_中孚-基于10_loss_InfoNCE_对比约束（标签原型）.py
# !python 16_中孚-基于10_loss_InfoNCE_对比约束（标签原型）.py
# Out:
# /home/xiuminke/miniconda3/envs/ml12/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 成功导入 diffusers 库
# 使用设备: cuda
# 电商文本到图像生成 - Diffusion 版
#
# === 开始训练 (Diffusion Mode) ===
# 检查模型保存目录: /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-T2I/plan_1/models/v16
# 发现最新检查点文件: /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-T2I/plan_1/models/v16/latest_checkpoint.ckpt
# 当前分片已完成，将从分片 4 开始训练
# SD VAE模型加载成功
#
# === 加载最新检查点: /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-T2I/plan_1/models/v16/latest_checkpoint.ckpt ===
# 模型状态加载成功
# 优化器状态加载成功
# 梯度缩放器状态加载成功
# 成功加载检查点
# 检查点保存时的损失: 0.2711
#
# === 训练参数设置 ===
# 总训练图片数: 4000
# 每次加载图片数: 1000
# 总分片数: 4
# 每个分片训练轮数: 5
# 批次大小: 4
#
# === 所有分片训练完成 ===
#
# 准备验证数据...
#
# === 开始生成图像 ===
# ...

# %%
# !python 17_小过-基于10_loss_边缘or结构感知的正则.py
# !python 17_小过-基于10_loss_边缘or结构感知的正则.py
# !python 17_小过-基于10_loss_边缘or结构感知的正则.py
# Out:
# /home/xiuminke/miniconda3/envs/ml12/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 成功导入 diffusers 库
# 使用设备: cuda
# 电商文本到图像生成 - Diffusion 版
#
# === 开始训练 (Diffusion Mode) ===
# 检查模型保存目录: /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-T2I/plan_1/models/v17
# 发现最新检查点文件: /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-T2I/plan_1/models/v17/latest_checkpoint.ckpt
# 当前分片已完成，将从分片 4 开始训练
# SD VAE模型加载成功
#
# === 加载最新检查点: /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-T2I/plan_1/models/v17/latest_checkpoint.ckpt ===
# 模型状态加载成功
# 优化器状态加载成功
# 梯度缩放器状态加载成功
# 成功加载检查点
# 检查点保存时的损失: 0.2533
#
# === 训练参数设置 ===
# 总训练图片数: 4000
# 每次加载图片数: 1000
# 总分片数: 4
# 每个分片训练轮数: 5
# 批次大小: 4
#
# === 所有分片训练完成 ===
#
# 准备验证数据...
#
# === 开始生成图像 ===
# ...

# %%
# !python 18_既济-基于10_other_类均衡采样与Batch构型.py
# !python 18_既济-基于10_other_类均衡采样与Batch构型.py
# !python 18_既济-基于10_other_类均衡采样与Batch构型.py
# Out:
# /home/xiuminke/miniconda3/envs/ml12/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 成功导入 diffusers 库
# 使用设备: cuda
# 电商文本到图像生成 - Diffusion 版
#
# === 开始训练 (Diffusion Mode) ===
# 正在加载标签文件: /mnt/d/forCoding_code/Tianchi_MUGE/ECommerce-T2I/plan_2/1-利用文本进行分类/classification_results_coarse.csv
# 成功加载 5000 个标签用于类均衡采样
# 检查模型保存目录: /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-T2I/plan_1/models/v18
# 发现最新检查点文件: /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-T2I/plan_1/models/v18/latest_checkpoint.ckpt
# 当前分片已完成，将从分片 4 开始训练
# SD VAE模型加载成功
#
# === 加载最新检查点: /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-T2I/plan_1/models/v18/latest_checkpoint.ckpt ===
# 模型状态加载成功
# 优化器状态加载成功
# 梯度缩放器状态加载成功
# 成功加载检查点
# 检查点保存时的损失: 0.1889
#
# === 训练参数设置 ===
# ...

# %%
# !python 19_未济-基于10_other_文本+标签双引导.py
# !python 19_未济-基于10_other_文本+标签双引导.py
# !python 19_未济-基于10_other_文本+标签双引导.py
# Out:
# /home/xiuminke/miniconda3/envs/ml12/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 成功导入 diffusers 库
# 使用设备: cuda
# 电商文本到图像生成 - Diffusion 版
#
# === 开始训练 (Diffusion Mode) ===
# 检查模型保存目录: /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-T2I/plan_1/models/v19
# 发现最新检查点文件: /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-T2I/plan_1/models/v19/latest_checkpoint.ckpt
# 当前分片已完成，将从分片 4 开始训练
# SD VAE模型加载成功
#
# === 加载最新检查点: /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-T2I/plan_1/models/v19/latest_checkpoint.ckpt ===
# 模型状态加载成功
# 优化器状态加载成功
# 梯度缩放器状态加载成功
# 成功加载检查点
# 检查点保存时的损失: 0.2087
#
# === 训练参数设置 ===
# 总训练图片数: 4000
# 每次加载图片数: 1000
# 总分片数: 4
# 每个分片训练轮数: 5
# 批次大小: 4
#
# === 所有分片训练完成 ===
#
# 准备验证数据...
#
# === 开始生成图像 ===
# ...

# %%
# !python 20_乾-基于10_other_两阶段采样（先类后文）.py
# !python 20_乾-基于10_other_两阶段采样（先类后文）.py
# !python 20_乾-基于10_other_两阶段采样（先类后文）.py
# Out:
# /home/xiuminke/miniconda3/envs/ml12/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 成功导入 diffusers 库
# 使用设备: cuda
# 电商文本到图像生成 - Diffusion 版
#
# === 开始训练 (Diffusion Mode) ===
# 检查模型保存目录: /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-T2I/plan_1/models/v20
# 发现最新检查点文件: /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-T2I/plan_1/models/v20/latest_checkpoint.ckpt
# 当前分片已完成，将从分片 4 开始训练
# SD VAE模型加载成功
#
# === 加载最新检查点: /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-T2I/plan_1/models/v20/latest_checkpoint.ckpt ===
# 模型状态加载成功
# 优化器状态加载成功
# 梯度缩放器状态加载成功
# 成功加载检查点
# 检查点保存时的损失: 0.2165
#
# === 训练参数设置 ===
# 总训练图片数: 4000
# 每次加载图片数: 1000
# 总分片数: 4
# 每个分片训练轮数: 5
# 批次大小: 4
#
# === 所有分片训练完成 ===
#
# 准备验证数据...
#
# === 开始生成图像 ===
# ...

# %%
# !python 21_坤-基于10_other_采样步数与噪声日程优化.py ## 这个可以认为是一种超参。
# !python 21_坤-基于10_other_采样步数与噪声日程优化.py ## 这个可以认为是一种超参。
# !python 21_坤-基于10_other_采样步数与噪声日程优化.py ## 这个可以认为是一种超参。
# Out:
# /home/xiuminke/miniconda3/envs/ml12/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 成功导入 diffusers 库
# 使用设备: cuda
# 电商文本到图像生成 - Diffusion 版
#
# === 开始训练 (Diffusion Mode) ===
# 检查模型保存目录: /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-T2I/plan_1/models/v21
# 发现最新检查点文件: /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-T2I/plan_1/models/v21/latest_checkpoint.ckpt
# 当前分片已完成，将从分片 4 开始训练
# SD VAE模型加载成功
#
# === 加载最新检查点: /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-T2I/plan_1/models/v21/latest_checkpoint.ckpt ===
# 模型状态加载成功
# 优化器状态加载成功
# 梯度缩放器状态加载成功
# 成功加载检查点
# 检查点保存时的损失: 0.2508
#
# === 训练参数设置 ===
# 总训练图片数: 4000
# 每次加载图片数: 1000
# 总分片数: 4
# 每个分片训练轮数: 5
# 批次大小: 4
#
# === 所有分片训练完成 ===
#
# 准备验证数据...
#
# === 开始生成图像 ===
# ...

# %%
# !python 14_涣-基于10_emb_MoE路由由标签主导.py
# !python 14_涣-基于10_emb_MoE路由由标签主导.py
# Out:
# /home/xiuminke/miniconda3/envs/ml12/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 成功导入 diffusers 库
# 使用设备: cuda
# 成功加载标签数据: 5000 条记录, 12 个类别
# 电商文本到图像生成 - Diffusion 版
#
# === 开始训练 (Diffusion Mode) ===
# 检查模型保存目录: /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-T2I/plan_1/models/v14
# 发现最新检查点文件: /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-T2I/plan_1/models/v14/latest_checkpoint.ckpt
# 当前分片已完成，将从分片 4 开始训练
# SD VAE模型加载成功
#
# === 加载最新检查点: /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-T2I/plan_1/models/v14/latest_checkpoint.ckpt ===
# 模型状态加载成功
# 优化器状态加载成功
# 梯度缩放器状态加载成功
# 成功加载检查点
# 检查点保存时的损失: 0.2125
#
# === 训练参数设置 ===
# 总训练图片数: 4000
# 每次加载图片数: 1000
# 总分片数: 4
# 每个分片训练轮数: 5
# 批次大小: 4
#
# === 所有分片训练完成 ===
#
# 准备验证数据...
#
# ...

# %%
# !python 14_涣-基于10_emb_MoE路由由标签主导.py
# Out:
# /home/xiuminke/miniconda3/envs/ml12/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 成功导入 diffusers 库
# 使用设备: cuda
# 成功加载标签数据: 5000 条记录, 12 个类别
# 电商文本到图像生成 - Diffusion 版
#
# === 开始训练 (Diffusion Mode) ===
# 检查模型保存目录: /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-T2I/plan_1/models/v14
# 发现最新检查点文件: /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-T2I/plan_1/models/v14/latest_checkpoint.ckpt
# 当前分片已完成，将从分片 4 开始训练
# SD VAE模型加载成功
#
# === 加载最新检查点: /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-T2I/plan_1/models/v14/latest_checkpoint.ckpt ===
# 模型状态加载成功
# 优化器状态加载成功
# 梯度缩放器状态加载成功
# 成功加载检查点
# 检查点保存时的损失: 0.2125
#
# === 训练参数设置 ===
# 总训练图片数: 4000
# 每次加载图片数: 1000
# 总分片数: 4
# 每个分片训练轮数: 5
# 批次大小: 4
#
# === 所有分片训练完成 ===
#
# 准备验证数据...
#
# ...

# %%
# !python 13_兑-基于10_emb_条件调制.py
# !python 13_兑-基于10_emb_条件调制.py
# !python 13_兑-基于10_emb_条件调制.py
# Out:
# /home/xiuminke/miniconda3/envs/ml12/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 成功导入 diffusers 库
# 使用设备: cuda
# 成功加载标签数据: 5000 条记录, 12 个类别
# 电商文本到图像生成 - Diffusion 版
#
# === 开始训练 (Diffusion Mode) ===
# 检查模型保存目录: /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-T2I/plan_1/models/v13
# 发现最新检查点文件: /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-T2I/plan_1/models/v13/latest_checkpoint.ckpt
# 当前分片已完成，将从分片 4 开始训练
# SD VAE模型加载成功
#
# === 加载最新检查点: /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-T2I/plan_1/models/v13/latest_checkpoint.ckpt ===
# 模型状态加载成功
# 优化器状态加载成功
# 梯度缩放器状态加载成功
# 成功加载检查点
# 检查点保存时的损失: 0.2639
#
# === 训练参数设置 ===
# 总训练图片数: 4000
# 每次加载图片数: 1000
# 总分片数: 4
# 每个分片训练轮数: 5
# 批次大小: 4
#
# === 所有分片训练完成 ===
#
# 准备验证数据...
#
# ...

# %%
# !python 12_巽-基于10_emb_标签嵌入拼接到条件通道.py
# !python 12_巽-基于10_emb_标签嵌入拼接到条件通道.py
# !python 12_巽-基于10_emb_标签嵌入拼接到条件通道.py
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 829
# /home/xiuminke/miniconda3/envs/ml12/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 成功导入 diffusers 库
# 使用设备: cuda
# 成功加载标签数据: 5000 条记录, 12 个类别
# 类别列表: ['上衣类', '包袋', '器皿', '家居', '数码', '童装类', '美妆', '裙装类', '裤装类', '鞋类', '食品', '饰品']
# 电商文本到图像生成 - Diffusion 版 (with Coarse Label Embedding)
#
# === 开始训练 (Diffusion Mode) ===
# 检查模型保存目录: /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-T2I/plan_1/models/v12_emb
# 发现最新检查点文件: /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-T2I/plan_1/models/v12_emb/latest_checkpoint.ckpt
# 当前分片已完成，将从分片 4 开始训练
# SD VAE模型加载成功
#
# ...

# %%
# !python 10_丰-基于9_只用5000个样本来训练验证_baseline.py
# Out:
# /home/xiuminke/miniconda3/envs/ml12/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 成功导入 diffusers 库
# 使用设备: cuda
# 强制重新训练，删除模型目录: /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-T2I/plan_1/models/v10
# 电商文本到图像生成 - Diffusion 版
#
# === 开始训练 (Diffusion Mode) ===
# 检查模型保存目录: /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-T2I/plan_1/models/v10
# SD VAE模型加载成功
# 没有发现检查点，将从头开始训练
#
# === 训练参数设置 ===
# 总训练图片数: 10
# 每次加载图片数: 10
# 总分片数: 1
# 每个分片训练轮数: 2
# 批次大小: 4
#
# === 加载第 1/1 个分片 (10 张图片) ===
# 分片 1/1 - epoch 1/2: 100%|███████████| 3/3 [00:02<00:00,  1.10it/s, loss=0.985]
# 分片 1/1 - Epoch 1/2, 平均损失: 1.0494
#
# === 保存检查点到 /mnt/d/forCoding_data/Tianchi_MUGE/ECommerce-T2I/plan_1/models/v10/latest_checkpoint.ckpt ===
# 检查点保存成功
# ...

# %%
# !python 11_旅-基于10_MoE的专家数变多.py

# %%
# !head -n 1 /mnt/d/forCoding_data/Tianchi_MUGE/originalData/ECommerce-T2I/T2I_train.img.cls1.tsv
