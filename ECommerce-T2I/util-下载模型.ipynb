# %%
# !pip install diffusers
from diffusers import DDPMPipeline, DDIMPipeline, PNDMPipeline

# load model and scheduler
ddpm = DDPMPipeline.from_pretrained("/mnt/d/HuggingFaceModels/models--google--ddpm-cifar10-32/")  # you can replace DDPMPipeline with DDIMPipeline or PNDMPipeline for faster inference

# run pipeline in inference (sample random noise and denoise)
image = ddpm().images[0]


# save image
image.save("ddpm_generated_image.png")
# Out:
# ...
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:47<00:00, 20.84it/s]

# %%
from modelscope import snapshot_download
model_dir = snapshot_download('google-bert/bert-base-chinese',cache_dir='/mnt/d/ModelScopeModels/')
