# %%
for line in """*   **上衣类**：`外套_上衣_长袖`、`女装_印花_外套`、`上衣_外套_长袖`
*   **裤装类**：`裤子_牛仔裤_直筒`
*   **裙装类**：`连衣裙_裙子_女装`
*   **童装类**：`女童_童装_男童`
*   **鞋类**：`女鞋_单鞋_真皮`
*   **包袋**：`单肩_真皮_背包`
*   **饰品**：`耳环_项链_耳钉`、`韩国_帽子_头饰`
*   **家居**：`北欧_餐厅_中式`、`摆件_装饰_卡通`
*   **器皿**：`陶瓷_茶杯_茶壶`
*   **数码**：`手机_硅胶_保护套`
*   **美妆**：`补水_精华_毛孔`
*   **食品**：`零食_普洱茶_特产`""".split("\n"):
    print(line)
# Out:
# *   **上衣类**：`外套_上衣_长袖`、`女装_印花_外套`、`上衣_外套_长袖`
# *   **裤装类**：`裤子_牛仔裤_直筒`
# *   **裙装类**：`连衣裙_裙子_女装`
# *   **童装类**：`女童_童装_男童`
# *   **鞋类**：`女鞋_单鞋_真皮`
# *   **包袋**：`单肩_真皮_背包`
# *   **饰品**：`耳环_项链_耳钉`、`韩国_帽子_头饰`
# *   **家居**：`北欧_餐厅_中式`、`摆件_装饰_卡通`
# *   **器皿**：`陶瓷_茶杯_茶壶`
# *   **数码**：`手机_硅胶_保护套`
# *   **美妆**：`补水_精华_毛孔`
# *   **食品**：`零食_普洱茶_特产`

# %%
# Out:
# {'外套_上衣_长袖': '上衣类',
#  '女装_印花_外套': '上衣类',
#  '上衣_外套_长袖': '上衣类',
#  '裤子_牛仔裤_直筒': '裤装类',
#  '连衣裙_裙子_女装': '裙装类',
#  '女童_童装_男童': '童装类',
#  '女鞋_单鞋_真皮': '鞋类',
#  '单肩_真皮_背包': '包袋',
#  '耳环_项链_耳钉': '饰品',
#  '韩国_帽子_头饰': '饰品',
#  '北欧_餐厅_中式': '家居',
#  '摆件_装饰_卡通': '家居',
#  '陶瓷_茶杯_茶壶': '器皿',
#  '手机_硅胶_保护套': '数码',
#  '补水_精华_毛孔': '美妆',
#  '零食_普洱茶_特产': '食品'}

# %% [markdown]
# # 结合diffusion

# %%
## 或许可以考虑，对样本进行一波分类，然后再对待测图片进行分类，完后选择专业的模型来生成，可能效果会更好。

# %%
# !python 7_艮-基于4_尝试一下diffusion.py
## 20轮1000张图，表现超过了9。
## 训练更多图试试。--》好像也没有显著增益。
# Out:
# /home/xiuminke/miniconda3/envs/ml12/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 成功导入 diffusers 库
# 使用设备: cuda
# 电商文本到图像生成 - Diffusion 版
#
# === 开始训练 (Diffusion Mode) ===
# 检查模型保存目录: /mnt/d/forCoding_data/Tianchi_MUGE/plan_1/models/v7
# 发现 145 个检查点文件
# SD VAE模型加载成功
# /mnt/d/forCoding_code/Tianchi_MUGE/ECommerce-T2I/plan_1/7_艮-基于4_尝试一下diffusion.py:398: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
#
# === 加载最新检查点: /mnt/d/forCoding_data/Tianchi_MUGE/plan_1/models/v7/model_chunk_7_epoch_4.ckpt ===
# 模型状态加载成功
# 优化器状态加载成功
# 梯度缩放器状态加载成功
# 成功加载检查点，继续从分片 7, epoch 5 开始训练
# 检查点保存时的损失: 0.1242
#
# === 训练参数设置 ===
# ...

# %%
# !python 9_归妹-基于7_更复杂的核心架构.py
## 20轮1000张图，表现比7差点。可能是因为结构更复杂，需要更多轮数？
# Out:
# /home/xiuminke/miniconda3/envs/ml12/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 成功导入 diffusers 库
# 使用设备: cuda
# 电商文本到图像生成 - Diffusion 版
#
# === 开始训练 (Diffusion Mode) ===
# 检查模型保存目录: /mnt/d/forCoding_data/Tianchi_MUGE/plan_1/models/v9
# 发现 20 个检查点文件
# SD VAE模型加载成功
# /mnt/d/forCoding_code/Tianchi_MUGE/ECommerce-T2I/plan_1/9_归妹-基于7_更复杂的核心架构.py:643: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
#
# === 加载最新检查点: /mnt/d/forCoding_data/Tianchi_MUGE/plan_1/models/v9/model_chunk_0_epoch_19.ckpt ===
# 模型状态加载成功
# 优化器状态加载成功
# 梯度缩放器状态加载成功
# 成功加载检查点，继续从分片 0, epoch 20 开始训练
# 检查点保存时的损失: 0.1269
#
# === 训练参数设置 ===
# ...

# %%
## 所以啊，7看上去不错。我们可以先写一些代码，然后对比一下如果7跑更大规模会不会表现更好。

# %%
# !python 7_艮-基于4_尝试一下diffusion.py
## 使用diffusion还是有重大进步的。diffusion真伟大。
# Out:
# /home/xiuminke/miniconda3/envs/ml12/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 成功导入 diffusers 库
# 使用设备: cuda
# 电商文本到图像生成 - Diffusion 版
#
# === 开始训练 (Diffusion Mode) ===
# 检查模型保存目录: /mnt/d/forCoding_data/Tianchi_MUGE/plan_1/models/v7
# 发现 10 个检查点文件
# SD VAE模型加载成功
# /mnt/d/forCoding_code/Tianchi_MUGE/ECommerce-T2I/plan_1/7_艮-基于4_尝试一下diffusion.py:398: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
#
# === 加载最新检查点: /mnt/d/forCoding_data/Tianchi_MUGE/plan_1/models/v7/model_chunk_0_epoch_9.ckpt ===
# 模型状态加载成功
# 优化器状态加载成功
# 梯度缩放器状态加载成功
# 成功加载检查点，继续从分片 0, epoch 10 开始训练
# 检查点保存时的损失: 0.1184
#
# === 训练参数设置 ===
# ...

# %%
# !python 8_渐-基于7_索性去掉sdvae只留diffusion.py
## 可能是训练的力度还不够大，效果很一般。或许多训练几轮有帮助。
## 为什么生成的图片辣么绿？
# Out:
# /home/xiuminke/miniconda3/envs/ml12/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 成功导入 diffusers 库
# 使用设备: cuda
# 强制重新训练，删除模型目录: /mnt/d/forCoding_data/Tianchi_MUGE/plan_1/models/v8
# 电商文本到图像生成 - 无VAE直接Diffusion版
#
# === 开始训练 (Image Diffusion Mode) ===
# /mnt/d/forCoding_code/Tianchi_MUGE/ECommerce-T2I/plan_1/8_渐-基于7_索性去掉sdvae只留diffusion.py:269: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# 检查模型保存目录: /mnt/d/forCoding_data/Tianchi_MUGE/plan_1/models/v8
# 没有发现检查点，将从头开始训练
# 总分片数: 1, 批次大小: 4
#
# === 加载第 1/1 个分片 ===
# ...

# %% [markdown]
# # sdvae方法

# %%
## 后续可以修改loss的定义，由latent之间的差异改为最终图片之间的差异。

# %%
# !python 4_丰-改成黑白试试.py
## 换成黑白，fid确实降低了。看来黑白的确实能节省成本。
## 尝试对一批样本做很多epoch，看看会不会有所进步。
# Out:
# /home/xiuminke/miniconda3/envs/ml12/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 使用设备: cuda
# 电商文本到图像生成 - 初试
# 加载语言模型...
# 语言模型加载完成
#
# === 开始训练 ===
# 检查模型保存目录: /mnt/d/forCoding_data/Tianchi_MUGE/plan_1/models/v4
# 发现 40 个检查点文件
# SD VAE模型加载成功
# /mnt/d/forCoding_code/Tianchi_MUGE/ECommerce-T2I/plan_1/4_丰-改成黑白试试.py:415: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
#
# === 加载最新检查点: /mnt/d/forCoding_data/Tianchi_MUGE/plan_1/models/v4/model_chunk_0_epoch_39.ckpt ===
# 模型状态加载成功
# 优化器状态加载成功
# 梯度缩放器状态加载成功
# 成功加载检查点，继续从分片 0, epoch 40 开始训练
# 检查点保存时的损失: 0.0455
#
# === 训练参数设置 ===
# 总训练图片数: 100
# 每次加载图片数: 100
# ...

# %%
# !python 3_归妹-可保存模型.py
# Out:
# /home/xiuminke/miniconda3/envs/ml12/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 使用设备: cuda
# 电商文本到图像生成 - 初试
# 加载语言模型...
# 语言模型加载完成
#
# === 开始训练 ===
# 检查模型保存目录: /mnt/d/forCoding_data/Tianchi_MUGE/plan_1/models/v3
# 发现 20 个检查点文件
# SD VAE模型加载成功
# /mnt/d/forCoding_code/Tianchi_MUGE/ECommerce-T2I/plan_1/3_归妹-可保存模型.py:395: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
#
# === 加载最新检查点: /mnt/d/forCoding_data/Tianchi_MUGE/plan_1/models/v3/model_chunk_3_epoch_4.ckpt ===
# 模型状态加载成功
# 优化器状态加载成功
# 梯度缩放器状态加载成功
# 成功加载检查点，继续从分片 3, epoch 5 开始训练
# 检查点保存时的损失: 0.0270
#
# === 训练参数设置 ===
# 总训练图片数: 4000
# 每次加载图片数: 500
# ...

# %%
# !python 2_渐-加载诸多分片.py
# Out:
# /home/xiuminke/miniconda3/envs/ml12/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 使用设备: cuda
# 电商文本到图像生成 - 初试
# 加载语言模型...
# 语言模型加载完成
#
# === 开始训练 ===
# SD VAE模型加载成功
# /mnt/d/forCoding_code/Tianchi_MUGE/ECommerce-T2I/plan_1/2_渐-加载诸多分片.py:353: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
#
# === 加载第 1/4 个分片 (500 张图片) ===
# 分片 1/4 - epoch 1/5:   0%|                             | 0/125 [00:00<?, ?it/s]/mnt/d/forCoding_code/Tianchi_MUGE/ECommerce-T2I/plan_1/2_渐-加载诸多分片.py:402: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# ...

# %%
"/mnt/d/forCoding_data/Tianchi_MUGE/trained_models/ECommerce-T2I/plan_1/"
